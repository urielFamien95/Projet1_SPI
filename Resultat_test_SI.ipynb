# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel('resultats.xls',sheet_name=1,header=3)
data = data.drop(["Unnamed: 0","Unnamed: 1"],axis=1)
data1 = data
data2 = data
data4 = data

# %%
data.head(14)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info  Moy  Rang  Résultat
# 0        1      Famien uriel      A    10    16    18  NaN   NaN       NaN
# 1        2      Yetchi uriel      A    12    14    18  NaN   NaN       NaN
# 2        3    Famien Abraham    NaN    13    17    14  NaN   NaN       NaN
# 3        4     Herman Gbabre      A    15    16    10  NaN   NaN       NaN
# 4        5          Yoro Gba      A    13    14    10  NaN   NaN       NaN
# 5        6        Soro Kader      A     9     8    12  NaN   NaN       NaN
# 6        7     Gueu Mireille      A    10    10    20  NaN   NaN       NaN
# 7        8           Zoro Bi    NaN     8     7     9  NaN   NaN       NaN
# 8        9    Ettien Fabrice    NaN     9    10     4  NaN   NaN       NaN
# 9       10       Fall Abdoul      A    17    15    12  NaN   NaN       NaN
# 10      11     Samira Bonoua      A    10    10    15  NaN   NaN       NaN
# ...

# %%
for i in range(0,13):
    data.loc[i,'Moy'] = (data.loc[i,'Fran']*1+data.loc[i,'Math']*2+data.loc[i,'Info']*3)/(1+2+3)

# %%
data.head(14)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info        Moy  Rang  \
# 0        1      Famien uriel      A    10    16    18  16.000000   NaN
# 1        2      Yetchi uriel      A    12    14    18  15.666667   NaN
# 2        3    Famien Abraham    NaN    13    17    14  14.833333   NaN
# 3        4     Herman Gbabre      A    15    16    10  12.833333   NaN
# 4        5          Yoro Gba      A    13    14    10  11.833333   NaN
# 5        6        Soro Kader      A     9     8    12  10.166667   NaN
# 6        7     Gueu Mireille      A    10    10    20  15.000000   NaN
# 7        8           Zoro Bi    NaN     8     7     9   8.166667   NaN
# 8        9    Ettien Fabrice    NaN     9    10     4   6.833333   NaN
# 9       10       Fall Abdoul      A    17    15    12  13.833333   NaN
# 10      11     Samira Bonoua      A    10    10    15  12.500000   NaN
# 11      12       Bamba Alima      A    10    11    12  11.333333   NaN
# ...

# %%
data.loc[0,['Fran','Math','Info']]
# Out:
# Fran    10
# Math    16
# Info    18
# Name: 0, dtype: object

# %%
for i in range(0,13):
    data1.loc[i,'Moy'] = np.average([data1.loc[i,'Fran'],data1.loc[i,'Math'],data1.loc[i,'Info']],weights=[1,2,3])

# %%
data1.head(14)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info        Moy  Rang  \
# 0        1      Famien uriel      A    10    16    18  16.000000   NaN
# 1        2      Yetchi uriel      A    12    14    18  15.666667   NaN
# 2        3    Famien Abraham    NaN    13    17    14  14.833333   NaN
# 3        4     Herman Gbabre      A    15    16    10  12.833333   NaN
# 4        5          Yoro Gba      A    13    14    10  11.833333   NaN
# 5        6        Soro Kader      A     9     8    12  10.166667   NaN
# 6        7     Gueu Mireille      A    10    10    20  15.000000   NaN
# 7        8           Zoro Bi    NaN     8     7     9   8.166667   NaN
# 8        9    Ettien Fabrice    NaN     9    10     4   6.833333   NaN
# 9       10       Fall Abdoul      A    17    15    12  13.833333   NaN
# 10      11     Samira Bonoua      A    10    10    15  12.500000   NaN
# 11      12       Bamba Alima      A    10    11    12  11.333333   NaN
# ...

# %%
data1 = data

# %%
data1.head(14)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info        Moy  Rang  \
# 0        1      Famien uriel      A    10    16    18  16.000000   NaN
# 1        2      Yetchi uriel      A    12    14    18  15.666667   NaN
# 2        3    Famien Abraham    NaN    13    17    14  14.833333   NaN
# 3        4     Herman Gbabre      A    15    16    10  12.833333   NaN
# 4        5          Yoro Gba      A    13    14    10  11.833333   NaN
# 5        6        Soro Kader      A     9     8    12  10.166667   NaN
# 6        7     Gueu Mireille      A    10    10    20  15.000000   NaN
# 7        8           Zoro Bi    NaN     8     7     9   8.166667   NaN
# 8        9    Ettien Fabrice    NaN     9    10     4   6.833333   NaN
# 9       10       Fall Abdoul      A    17    15    12  13.833333   NaN
# 10      11     Samira Bonoua      A    10    10    15  12.500000   NaN
# 11      12       Bamba Alima      A    10    11    12  11.333333   NaN
# ...

# %%
data2['Moy'] = data2.apply(lambda x: np.average([x['Fran'],x['Math'],x['Info']],weights=[1,2,3]),axis=1)

# %%
data2.head(14)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info        Moy  Rang  \
# 0        1      Famien uriel      A    10    16    18  16.000000   NaN
# 1        2      Yetchi uriel      A    12    14    18  15.666667   NaN
# 2        3    Famien Abraham    NaN    13    17    14  14.833333   NaN
# 3        4     Herman Gbabre      A    15    16    10  12.833333   NaN
# 4        5          Yoro Gba      A    13    14    10  11.833333   NaN
# 5        6        Soro Kader      A     9     8    12  10.166667   NaN
# 6        7     Gueu Mireille      A    10    10    20  15.000000   NaN
# 7        8           Zoro Bi    NaN     8     7     9   8.166667   NaN
# 8        9    Ettien Fabrice    NaN     9    10     4   6.833333   NaN
# 9       10       Fall Abdoul      A    17    15    12  13.833333   NaN
# 10      11     Samira Bonoua      A    10    10    15  12.500000   NaN
# 11      12       Bamba Alima      A    10    11    12  11.333333   NaN
# ...

# %%
data1.head(14)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info        Moy  Rang  \
# 0        1      Famien uriel      A    10    16    18  16.000000   NaN
# 1        2      Yetchi uriel      A    12    14    18  15.666667   NaN
# 2        3    Famien Abraham    NaN    13    17    14  14.833333   NaN
# 3        4     Herman Gbabre      A    15    16    10  12.833333   NaN
# 4        5          Yoro Gba      A    13    14    10  11.833333   NaN
# 5        6        Soro Kader      A     9     8    12  10.166667   NaN
# 6        7     Gueu Mireille      A    10    10    20  15.000000   NaN
# 7        8           Zoro Bi    NaN     8     7     9   8.166667   NaN
# 8        9    Ettien Fabrice    NaN     9    10     4   6.833333   NaN
# 9       10       Fall Abdoul      A    17    15    12  13.833333   NaN
# 10      11     Samira Bonoua      A    10    10    15  12.500000   NaN
# 11      12       Bamba Alima      A    10    11    12  11.333333   NaN
# ...

# %%
data1.head(14)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info        Moy  Rang  \
# 0        1      Famien uriel      A    10    16    18  16.000000   NaN
# 1        2      Yetchi uriel      A    12    14    18  15.666667   NaN
# 2        3    Famien Abraham    NaN    13    17    14  14.833333   NaN
# 3        4     Herman Gbabre      A    15    16    10  12.833333   NaN
# 4        5          Yoro Gba      A    13    14    10  11.833333   NaN
# 5        6        Soro Kader      A     9     8    12  10.166667   NaN
# 6        7     Gueu Mireille      A    10    10    20  15.000000   NaN
# 7        8           Zoro Bi    NaN     8     7     9   8.166667   NaN
# 8        9    Ettien Fabrice    NaN     9    10     4   6.833333   NaN
# 9       10       Fall Abdoul      A    17    15    12  13.833333   NaN
# 10      11     Samira Bonoua      A    10    10    15  12.500000   NaN
# 11      12       Bamba Alima      A    10    11    12  11.333333   NaN
# ...

# %%
data1['Rang'] = data1['Moy'].rank(ascending=False).astype(int)

# %%
data1.head(14)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info        Moy  Rang  \
# 0        1      Famien uriel      A    10    16    18  16.000000     1
# 1        2      Yetchi uriel      A    12    14    18  15.666667     2
# 2        3    Famien Abraham    NaN    13    17    14  14.833333     4
# 3        4     Herman Gbabre      A    15    16    10  12.833333     6
# 4        5          Yoro Gba      A    13    14    10  11.833333     8
# 5        6        Soro Kader      A     9     8    12  10.166667    11
# 6        7     Gueu Mireille      A    10    10    20  15.000000     3
# 7        8           Zoro Bi    NaN     8     7     9   8.166667    12
# 8        9    Ettien Fabrice    NaN     9    10     4   6.833333    13
# 9       10       Fall Abdoul      A    17    15    12  13.833333     5
# 10      11     Samira Bonoua      A    10    10    15  12.500000     7
# 11      12       Bamba Alima      A    10    11    12  11.333333     9
# ...

# %%
data1['Résultat'] = data1.apply(lambda x: 'Admis' if x['Moy']>10.0 else 'Réfusé',axis=1)

# %%
data1.head(14)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info        Moy  Rang  \
# 0        1      Famien uriel      A    10    16    18  16.000000     1
# 1        2      Yetchi uriel      A    12    14    18  15.666667     2
# 2        3    Famien Abraham    NaN    13    17    14  14.833333     4
# 3        4     Herman Gbabre      A    15    16    10  12.833333     6
# 4        5          Yoro Gba      A    13    14    10  11.833333     8
# 5        6        Soro Kader      A     9     8    12  10.166667    11
# 6        7     Gueu Mireille      A    10    10    20  15.000000     3
# 7        8           Zoro Bi    NaN     8     7     9   8.166667    12
# 8        9    Ettien Fabrice    NaN     9    10     4   6.833333    13
# 9       10       Fall Abdoul      A    17    15    12  13.833333     5
# 10      11     Samira Bonoua      A    10    10    15  12.500000     7
# 11      12       Bamba Alima      A    10    11    12  11.333333     9
# ...

# %%
data1.describe()
# Out:
#          Numéro       Fran       Math       Info        Moy       Rang
# count  13.00000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    7.00000  10.769231  11.769231  13.230769  12.333333   6.923077
# std     3.89444   3.295296   3.833055   4.530523   2.813657   3.839738
# min     1.00000   4.000000   5.000000   4.000000   6.833333   1.000000
# 25%     4.00000   9.000000  10.000000  10.000000  11.333333   4.000000
# 50%     7.00000  10.000000  11.000000  12.000000  12.500000   7.000000
# 75%    10.00000  13.000000  15.000000  18.000000  14.833333   9.000000
# max    13.00000  17.000000  17.000000  20.000000  16.000000  13.000000

# %%
data3 = {'Statistiques': ['Moyenne générale','Plus forte moyenne','Plus faible moyenne','Nombre Admis','Nombre refusés']
        }

# %%
data3
# Out:
# {'Statistiques': ['Moyenne générale',
#   'Plus forte moyenne',
#   'Plus faible moyenne',
#   'Nombre Admis',
#   'Nombre refusés']}

# %%
#df = pd.DataFrame(data3, columns= ['Statistiques'])

# %%
#df['Note'] = data1['Moy'].mean()
#df

# %%
import pandas as pd
df = pd.DataFrame({
    "Statistiques" : ['Moyenne générale','Plus forte moyenne','Plus faible moyenne','Nombre Admis','Nombre refusés'],
    #" " : [12.333333,16.000000,6.833333,11,2]
   })

# %%
df
# Out:
#           Statistiques
# 0     Moyenne générale
# 1   Plus forte moyenne
# 2  Plus faible moyenne
# 3         Nombre Admis
# 4       Nombre refusés

# %%
import matplotlib.pyplot as plt
Statistiques = ['Nombre Admis','Nombre Refusés']
Score = [11,2]
plt.pie(Score,labels=Statistiques,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c8d0646fd0>,
# ...
#  [Text(-0.9740016429451693, 0.5111954611888794, 'Nombre Admis'),
#   Text(0.9740016668759548, -0.5111954155925714, 'Nombre Refusés')],
#  [Text(-0.5312736234246378, 0.2788338879212069, '84.6%'),
#   Text(0.5312736364777935, -0.27883386305049346, '15.4%')])

# %%
data4.head(13)
# Out:
#     Numéro    Nom et prénoms Statut  Fran  Math  Info        Moy  Rang  \
# 0        1      Famien uriel      A    10    16    18  16.000000     1
# 1        2      Yetchi uriel      A    12    14    18  15.666667     2
# 2        3    Famien Abraham    NaN    13    17    14  14.833333     4
# 3        4     Herman Gbabre      A    15    16    10  12.833333     6
# 4        5          Yoro Gba      A    13    14    10  11.833333     8
# 5        6        Soro Kader      A     9     8    12  10.166667    11
# 6        7     Gueu Mireille      A    10    10    20  15.000000     3
# 7        8           Zoro Bi    NaN     8     7     9   8.166667    12
# 8        9    Ettien Fabrice    NaN     9    10     4   6.833333    13
# 9       10       Fall Abdoul      A    17    15    12  13.833333     5
# 10      11     Samira Bonoua      A    10    10    15  12.500000     7
# 11      12       Bamba Alima      A    10    11    12  11.333333     9
# ...

# %%
import pandas as pd
#df = pd.DataFrame({
  #  "Statistiques" : ['Moyenne générale','Plus forte moyenne','Plus faible moyenne','Nombre Admis','Nombre refusés'],
    #" " : [12.333333,16.000000,6.833333,11,2]
  # })

def moy(tableau):
    for i in tableau.columns[6::6]:
        moyenne=tableau[i].mean()
    return(moyenne)
moyf=moy(data4)
    
def mini(tableau):
    for i in tableau.columns[6::6]:
        minimum=tableau[i].min()
    return(minimum)
    #print(i)    
minf=mini(data4)

def max(tableau):
    for i in tableau.columns[6::6]:
        maximun=tableau[i].max()
    return(maximun)
    #print(i)    
maxf=max(data4)



df = pd.DataFrame({
    "Statistiques" : ['Moyenne générale','Plus forte moyenne','Plus faible moyenne','Nombre Admis','Nombre refusés'],
    " " : [moyf,maxf,minf,11,2]
   })

# %%
df
# Out:
#           Statistiques
# 0     Moyenne générale  12.333333
# 1   Plus forte moyenne  16.000000
# 2  Plus faible moyenne   6.833333
# 3         Nombre Admis  11.000000
# 4       Nombre refusés   2.000000
